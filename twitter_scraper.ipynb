# %%
import pandas as pd
import numpy as np

# %%
df_power = pd.read_json('tweets.json')

# %%
df_power.head(4)
# Out:
#    has_media                               hashtags img_urls  is_replied  \
# 0      False                          [poweroutage]       []       False
# 1      False  [iPhone, panthers, poweroutage, ncwx]       []       False
# 2      False          [Poweroutage, Beddingestrand]       []       False
# 3      False                          [PowerOutage]       []       False
#
#    is_reply_to  likes links parent_tweet_id  replies reply_to_users  ...  \
# 0        False      0    []                        0             []  ...
# 1        False      0    []                        0             []  ...
# 2        False      0    []                        0             []  ...
# 3        False      0    []                        0             []  ...
#
#        screen_name                                               text  \
# 0      PDXSaluling  #poweroutage ..does my house belong to tomorro...
# 1     shellyleslie  Is it sad that I am sitting in my car charging...
# ...

# %%
df_power['text_html']
# Out:
# 0      <p class="TweetTextSize js-tweet-text tweet-te...
# 1      <p class="TweetTextSize js-tweet-text tweet-te...
# 2      <p class="TweetTextSize js-tweet-text tweet-te...
# 3      <p class="TweetTextSize js-tweet-text tweet-te...
# 4      <p class="TweetTextSize js-tweet-text tweet-te...
#                              ...
# 307    <p class="TweetTextSize js-tweet-text tweet-te...
# 308    <p class="TweetTextSize js-tweet-text tweet-te...
# 309    <p class="TweetTextSize js-tweet-text tweet-te...
# 310    <p class="TweetTextSize js-tweet-text tweet-te...
# 311    <p class="TweetTextSize js-tweet-text tweet-te...
# Name: text_html, Length: 312, dtype: object
