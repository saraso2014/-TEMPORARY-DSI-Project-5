# %%
import pandas as pd


df = pd.read_json('./obama.json')

# %%
df[['text','username','hashtags']]
# Out:
#                                                   text  \
# 0    Criticize but offer not real solution. That's ...
# 1    Photo by @krazen #HOODROCK2 with #JayBraun Dyl...
# 2    Photo by @krazen #HOODROCK2 with #JayBraun Dyl...
# 3    Photo by @krazen #HOODROCK2 with #JayBraun Dyl...
# 4    Photo by @krazen #HOODROCK2 with #JayBraun Dyl...
# ..                                                 ...
# 271  Biden will have to address the Kids in Cages b...
# 272  Thank you @BarackObama. Addressing the seniors...
# 273  Trump repeatedly has said supply chain issues ...
# 274  As in, Media and Obama needing to interfere in...
# 275  President Barack Obama will headline a televis...
#
#                        username               hashtags
# 0    Joe vs the Fascist Volcano                     []
# 1            YJ aka Young Jimmy  [HOODROCK2, JayBraun]
# 2            YJ aka Young Jimmy  [HOODROCK2, JayBraun]
# 3            YJ aka Young Jimmy  [HOODROCK2, JayBraun]
# ...

# %%
df[['text','username','hashtags']].to_csv('./obama.csv')
